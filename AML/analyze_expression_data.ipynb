# %%
import pandas as pd
import numpy as np

# %%
base_path = "../nanodiag_datasets/"
df_expression_data = pd.read_csv(base_path + "df_expression_data_transpose.csv", sep="\t")
df_expression_data
# Out:
#      Unnamed: 0   MIR33A    MIR1206    OTTHUMG00000164201    SNORA76   \
# 0    01004-d0-1   2.85713    2.85184               2.82945    2.89834
# 1    01004-d0-2   2.81492    2.87814               2.87172    2.87163
# 2    01004-d0-3   2.82639    2.83133               2.87381    2.86321
# 3    01004-d8-1   2.88884    2.97808               3.01110    2.87181
# 4    01004-d8-2   2.79423    2.85958               2.87631    2.83322
# ..          ...       ...        ...                   ...        ...
# 128  31001-d0-2   2.90543    3.11199               2.86342    2.90930
# 129  31001-d0-3   2.96855    3.14358               2.87237    2.83605
# 130  31001-d8-1   2.95168    3.22401               2.85726    2.85843
# 131  31001-d8-2   2.90797    3.45967               3.05210    2.85239
# 132  31001-d8-3   2.97106    3.42560               3.04773    2.90134
#
#       MIR4310    MIR767    MIR588    MIR1224    MIR1539   ...   RPL41P2   \
# 0      2.83211   2.95627   2.88588    2.87711    2.89744  ...    12.2635
# 1      2.97847   2.84895   2.92049    2.91259    2.88129  ...    12.2195
# 2      2.84630   2.86582   2.87155    2.90190    2.92618  ...    12.3291
# 3      2.94683   2.89678   2.99720    2.92212    2.91474  ...    12.2578
# 4      2.91773   2.90924   2.94821    2.88572    2.88825  ...    12.2516
# ..         ...       ...       ...        ...        ...  ...        ...
# 128    2.92648   2.94460   2.89645    2.90972    2.89135  ...    12.1867
# 129    2.89057   2.90284   2.98542    2.82556    2.88059  ...    12.2983
# 130    2.90621   2.93604   2.91956    2.76500    2.84572  ...    12.3627
# 131    2.82881   2.91156   2.96702    2.83203    2.91249  ...    12.3028
# 132    2.89111   2.91427   2.94584    2.85624    2.91045  ...    12.2780
#
#       SLC44A4 .7   RN7SL1    RN7SK    LOC100652902    RPS11    PGAP2 .1  \
# 0        12.4998   12.5222  12.5868         12.7037  12.6678    12.8254
# 1        12.4282   12.4846  12.5606         12.6702  12.7296    12.7793
# 2        12.4391   12.3750  12.5910         12.6912  12.7312    12.8282
# 3        12.5087   12.4114  12.5587         12.7487  12.7239    12.7623
# 4        12.6202   12.4850  12.6126         12.7186  12.7185    12.9190
# ..           ...       ...      ...             ...      ...        ...
# 128      12.4015   12.7268  12.4005         12.6839  12.7669    12.6150
# 129      12.5912   12.7486  12.4259         12.7861  12.7122    12.7693
# 130      12.5269   12.9152  12.5442         12.7709  12.7265    12.8159
# 131      12.5721   12.7646  12.4970         12.7670  12.7883    12.7604
# 132      12.3992   12.8354  12.5019         12.7512  12.8093    12.6334
#
#       LOC100653008    MCCC1-AS1   treatment_label
# 0           12.8561      13.0124                0
# 1           12.8246      12.9185                0
# 2           12.7987      12.8173                0
# 3           12.9563      12.9617                1
# 4           12.8264      12.9368                1
# ..              ...          ...              ...
# 128         12.9991      12.7285                0
# 129         12.9366      13.0041                0
# 130         12.9565      12.8502                1
# 131         12.9229      12.7715                1
# 132         12.9928      12.7398                1
#
# [133 rows x 32672 columns]

# %%
sample_names = df_expression_data["Unnamed: 0"]
labels = df_expression_data["treatment_label"]
sample_names, labels
# Out:
# (0      01004-d0-1
#  1      01004-d0-2
#  2      01004-d0-3
#  3      01004-d8-1
#  4      01004-d8-2
#            ...
#  128    31001-d0-2
#  129    31001-d0-3
#  130    31001-d8-1
#  131    31001-d8-2
#  132    31001-d8-3
#  Name: Unnamed: 0, Length: 133, dtype: object,
#  0      0
#  1      0
#  2      0
#  3      1
#  4      1
#        ..
#  128    0
#  129    0
#  130    1
#  131    1
#  132    1
#  Name: treatment_label, Length: 133, dtype: int64)

# %%
df_expression_data_feature = df_expression_data.drop(columns=["Unnamed: 0", "treatment_label"])
df_expression_data_feature
# Out:
#       MIR33A    MIR1206    OTTHUMG00000164201    SNORA76    MIR4310   \
# 0     2.85713    2.85184               2.82945    2.89834    2.83211
# 1     2.81492    2.87814               2.87172    2.87163    2.97847
# 2     2.82639    2.83133               2.87381    2.86321    2.84630
# 3     2.88884    2.97808               3.01110    2.87181    2.94683
# 4     2.79423    2.85958               2.87631    2.83322    2.91773
# ..        ...        ...                   ...        ...        ...
# 128   2.90543    3.11199               2.86342    2.90930    2.92648
# 129   2.96855    3.14358               2.87237    2.83605    2.89057
# 130   2.95168    3.22401               2.85726    2.85843    2.90621
# 131   2.90797    3.45967               3.05210    2.85239    2.82881
# 132   2.97106    3.42560               3.04773    2.90134    2.89111
#
#       MIR767    MIR588    MIR1224    MIR1539    MIR4752   ...   MIR1273A   \
# 0     2.95627   2.88588    2.87711    2.89744    2.92549  ...     12.2919
# 1     2.84895   2.92049    2.91259    2.88129    2.92637  ...     12.1913
# 2     2.86582   2.87155    2.90190    2.92618    2.86416  ...     12.2101
# 3     2.89678   2.99720    2.92212    2.91474    2.95133  ...     12.2108
# 4     2.90924   2.94821    2.88572    2.88825    2.91266  ...     12.3311
# ..        ...       ...        ...        ...        ...  ...         ...
# 128   2.94460   2.89645    2.90972    2.89135    2.94889  ...     12.0103
# 129   2.90284   2.98542    2.82556    2.88059    2.93916  ...     12.2411
# 130   2.93604   2.91956    2.76500    2.84572    2.90358  ...     12.1956
# 131   2.91156   2.96702    2.83203    2.91249    3.01148  ...     12.1977
# 132   2.91427   2.94584    2.85624    2.91045    2.92732  ...     12.1339
#
#       RPL41P2    SLC44A4 .7   RN7SL1    RN7SK    LOC100652902    RPS11   \
# 0      12.2635      12.4998   12.5222  12.5868         12.7037  12.6678
# 1      12.2195      12.4282   12.4846  12.5606         12.6702  12.7296
# 2      12.3291      12.4391   12.3750  12.5910         12.6912  12.7312
# 3      12.2578      12.5087   12.4114  12.5587         12.7487  12.7239
# 4      12.2516      12.6202   12.4850  12.6126         12.7186  12.7185
# ..         ...          ...       ...      ...             ...      ...
# 128    12.1867      12.4015   12.7268  12.4005         12.6839  12.7669
# 129    12.2983      12.5912   12.7486  12.4259         12.7861  12.7122
# 130    12.3627      12.5269   12.9152  12.5442         12.7709  12.7265
# 131    12.3028      12.5721   12.7646  12.4970         12.7670  12.7883
# 132    12.2780      12.3992   12.8354  12.5019         12.7512  12.8093
#
#       PGAP2 .1   LOC100653008    MCCC1-AS1
# 0      12.8254         12.8561      13.0124
# 1      12.7793         12.8246      12.9185
# 2      12.8282         12.7987      12.8173
# 3      12.7623         12.9563      12.9617
# 4      12.9190         12.8264      12.9368
# ..         ...             ...          ...
# 128    12.6150         12.9991      12.7285
# 129    12.7693         12.9366      13.0041
# 130    12.8159         12.9565      12.8502
# 131    12.7604         12.9229      12.7715
# 132    12.6334         12.9928      12.7398
#
# [133 rows x 32670 columns]

# %%
from xgboost import XGBClassifier
from matplotlib import pyplot

# %%
model = XGBClassifier()
model.fit(df_expression_data_feature, labels)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# feature importance
df_expression_data_feature
# plot
pyplot.bar(range(len(model.feature_importances_)), model.feature_importances_)
pyplot.show()
# Out:
# [0.00173775 0.00183578 0.         ... 0.         0.         0.        ]

# %%
feature_imps = pd.DataFrame(zip(df_expression_data_feature.columns, model.feature_importances_), columns=["Gene", "Importance"])

# %%
feature_imps
# Out:
#                        Gene  Importance
# 0                   MIR33A     0.001738
# 1                  MIR1206     0.001836
# 2       OTTHUMG00000164201     0.000000
# 3                  SNORA76     0.000000
# 4                  MIR4310     0.000000
# ...                     ...         ...
# 32665         LOC100652902     0.000000
# 32666                RPS11     0.000000
# 32667              PGAP2 .1    0.000000
# 32668         LOC100653008     0.000000
# 32669            MCCC1-AS1     0.000000
#
# [32670 rows x 2 columns]

# %%
feature_imps = feature_imps.sort_values(ascending=False, by="Importance")
feature_imps = feature_imps[feature_imps["Importance"] > 0.0]
feature_imps
# Out:
#                        Gene  Importance
# 25360                 CFL2     0.086460
# 2475    OTTHUMG00000008128     0.085255
# 8705                  ANLN     0.059946
# 15508               CHST13     0.056331
# 2164               MIR3147     0.048570
# ...                     ...         ...
# 15658   OTTHUMG00000001449     0.000732
# 21272                SNX20     0.000641
# 439     OTTHUMG00000020021     0.000612
# 2870    OTTHUMG00000149338     0.000292
# 31115              ATP6AP2     0.000149
#
# [86 rows x 2 columns]

# %%
feature_imps.to_csv(base_path + "significant_genes.csv", sep="\t", index=None)

# %%
groud_truth_genes = pd.read_csv(base_path + "ground_truth_genes.csv", sep="\t")
groud_truth_genes
# Out:
#    Gene symbol
# 0       KCNAB1
# 1      SLITRK6
# 2        FCRL1
# 3        IFI27
# 4        GPR63
# ..         ...
# 82     ST8SIA6
# 83        GZMA
# 84       ABCA9
# 85     GALNTL6
# 86      MRPL50
#
# [87 rows x 1 columns]

# %%
true_genes = groud_truth_genes["Gene symbol"].tolist()

# %%
pred_genes = feature_imps["Gene"].tolist()
pred_genes = [item.strip() for item in pred_genes]

# %%
intersection = list(set(true_genes).intersection(set(pred_genes)))
intersection
# Out:
# ['KLF1', 'ERN1', 'DCAF4L1']
